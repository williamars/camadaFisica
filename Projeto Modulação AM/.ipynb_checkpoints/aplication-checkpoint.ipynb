# %% [markdown]
# Camada Física da Computação 2020/2
#
# ## Projeto Modulação AM
#
#
# William Silva williamars@insper.edu.br

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from scipy import signal
from scipy.fftpack import fft, fftshift
from suaBibSignal import signalMeu
import sounddevice as sd
import soundfile   as sf
sd.default.samplerate = fs
sd.default.channels = 1

# %% [markdown]
# #### Função Low Pass

# %%
def LPF(signal, cutoff_hz, fs):
    from scipy import signal as sg
    #####################
    # Filtro
    #####################
    # https://scipy.github.io/old-wiki/pages/Cookbook/FIRFilter.html
    nyq_rate = fs/2
    width = 5.0/nyq_rate
    ripple_db = 120.0 #dB
    N , beta = sg.kaiserord(ripple_db, width)
    taps = sg.firwin(N, cutoff_hz/nyq_rate, window=('kaiser', beta))
    return( sg.lfilter(taps, 1.0, signal))

# %% [markdown]
# ## Propriedades dos sinais

# %%
fs  = 44100
A   = 1.5
F   = 1
T   = 4
t   = np.linspace(-T/2,T/2,T*fs)

# %% [markdown]
# Inicializando a biblioteca para utilizar as funções

# %%
mySignal = signalMeu()

# %% [markdown]
# ### Tocando o som

# %%
audio, samplerate = sf.read('camFis.wav')
yAudio = audio[:,1]
samplesAudio = len(yAudio)
sd.play(audio)
sd.wait()

# %% [markdown]
# ## Gráfico

# %%
plt.plot(yAudio)

# %%
maior = max(yAudio)
menor = min(yAudio)

choose = 0
if maior > np.abs(menor):
    choose = np.abs(maior)
else:
    choose = np.abs(menor)

newSignal = yAudio/choose
plt.plot(newSignal, 'purple')
sd.play(newSignal)
sd.wait()

# %%
X, Y = mySignal.calcFFT(newSignal, fs)
plt.plot(X, np.abs(Y))

# %% [markdown]
# ## Filtrando

# %%
yFiltrado = LPF(newSignal, 4000, fs)
sd.play(yFiltrado)
sd.wait()
